# %%
import pandas as pd

# %%
whole = pd.read_csv('Mental_Health_Care_in_the_Last_4_Weeks.csv')

# %%
whole = whole.drop(['Time Period Start Date', 'Time Period End Date',
                    'Quartile Range', 'Suppression Flag'], axis=1)

# %%
whole
# Out:
#                                                Indicator              Group  \
# 0      Took Prescription Medication for Mental Health...  National Estimate
# 1      Took Prescription Medication for Mental Health...             By Age
# 2      Took Prescription Medication for Mental Health...             By Age
# 3      Took Prescription Medication for Mental Health...             By Age
# 4      Took Prescription Medication for Mental Health...             By Age
# ...                                                  ...                ...
# 10399  Needed Counseling or Therapy But Did Not Get I...           By State
# 10400  Needed Counseling or Therapy But Did Not Get I...           By State
# 10401  Needed Counseling or Therapy But Did Not Get I...           By State
# 10402  Needed Counseling or Therapy But Did Not Get I...           By State
# 10403  Needed Counseling or Therapy But Did Not Get I...           By State
#
# ...

# %%
questions = whole['Indicator'].unique()

# %%
question1 = whole[whole['Indicator'] == questions[0]]
question2 = whole[whole['Indicator'] == questions[1]]
question3 = whole[whole['Indicator'] == questions[2]]
question4 = whole[whole['Indicator'] == questions[3]]

# %%
question4['Age'] = question4.apply(lambda row: row['Subgroup'] if 'By Age' in row['Group'] else pd.NA, axis=1)
question4['Sex'] = question4.apply(lambda row: row['Subgroup'] if 'By Sex' in row['Group'] else pd.NA, axis=1)
question4['State'] = question4.apply(lambda row: row['Subgroup'] if 'By State' in row['Group'] else pd.NA, axis=1)
question4['Symptoms_Presence'] = question4.apply(lambda row: row['Subgroup'] if 'By Presence of Symptoms of Anxiety/Depression' in row['Group'] else pd.NA, axis=1)
question4['Education'] = question4.apply(lambda row: row['Subgroup'] if 'By Education' in row['Group'] else pd.NA, axis=1)
# Out:
# /var/folders/rr/3fvk4bt93130f2t0msg4_5n80000gn/T/ipykernel_79488/3598061795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   question4['Age'] = question4.apply(lambda row: row['Subgroup'] if 'By Age' in row['Group'] else pd.NA, axis=1)
# /var/folders/rr/3fvk4bt93130f2t0msg4_5n80000gn/T/ipykernel_79488/3598061795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   question4['Sex'] = question4.apply(lambda row: row['Subgroup'] if 'By Sex' in row['Group'] else pd.NA, axis=1)
# ...

# %%
#question4.head(20)

# %%
cat_labels = [
  'Age',
  'Sex',
  'State',
  'Symptoms_Presence',
  'Education'
]

#Sets of all categories in a particular column
cats_sets = [question4.loc[:, label].fillna('NaN').unique() for label in cat_labels]

# %%
def onehot(column=None, col=None):
    
    a = len(column)
    b = len(col)
    temp = np.zeros((a,b))
    for i in range(a):
        cat = column.iloc[i]
        if cat in col:
            j = np.where(col == cat)[0][0]
            temp[i][j] = 1

    return temp
